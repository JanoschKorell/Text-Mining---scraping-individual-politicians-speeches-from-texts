# %%
import re

# %%
#Individual changes to individual words
def replace_delete(text):
            
            import re
            
            text = re.sub(' \n', '\n', text)
            text = re.sub('  ', ' ', text)
            text = re.sub(r'\/', '', text)
            text = re.sub(r'\(Gunther', 'Gunther', text)
            text = re.sub(r'Dr\. ', '', text,   flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'h. c. ', '', text,  flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(A\)', '', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(B\)', '', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(C\)', '', text, flags=re.DOTALL  | re.MULTILINE)  
            text = re.sub(r'\(D\)', '', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'Wort\n', 'Wort.\n\n', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\, Bundesminister', ' Bundesminister', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'Canan Bayram\,', 'Canan Bayram.', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\, Parl \.', ' Parl.', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\, Parl\.', ' Parl.', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'erinnern\:', 'erinnern \:', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'Martin Sichert \(AfD\)\:', 'Martin Sichert [AfD]:', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'Grüneotz \(Grüne\)\:', 'Grüneotz \(Grüne\)', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'Volkmar Klein \(CDUCSU\):', 'Volkmar Klein [CDUCSU]:', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(KFOR\)\:', '\(KFOR\) ', text, flags=re.DOTALL  | re.MULTILINE) 
            text = re.sub(r'\(UNIFIL\)\:', '\(UNIFIL\) ', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(NUACA\)', '', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\(Fortsetzung\)\:', '(Fortsetzung)', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\(DIE LINKE\)', '(DIELINKE)', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\[DIE LINKE\]', '[DIELINKE]', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(CDU\nCSU\)', '(CDUCSU)', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(AfD\) \:', '(AfD):', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'\(Univ Kyiv\) ', '', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Senator', ' Senator', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Senatorin', ' Senatorin', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Staatsministerin', ' Staatsministerin', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Staatsminister', ' Staatsminister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Regierender Bürgermeister', ' Regierender Bürgermeister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Minister', ' Minister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Bürgermeister', ' Bürgermeister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Staatssekretär', ' Staatssekretär', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\, Bundesministerin', ' Bundesministerin', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bundes-\nkanzleramt', 'Bundeskanzleramt', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bun-\ndesminister', 'Bundesminister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bun-\ndesminister', 'Bundesminister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bundes-\nminister', 'Bundesminister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Staatssekretä-\nrin', 'Staatssekretärin', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Finan-\nzen\:', 'Finanzen:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Thomas de', 'Thomas De', text, flags=re.DOTALL  | re.MULTILINE).strip() 

            text = re.sub(r'Bundeskanz\-lerin', 'Bundeskanzlerin', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Sozi\-ales', 'Soziales', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bundesminis\-ter', 'Bundesminister', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Auswär\-tigen', 'Auswärtigen', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Entwick\-lung', 'Entwicklung', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Bundesmi\-nister', 'Bundesminister ', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'https:', '', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'http:', '', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'erklärt hat\:', 'erklärt hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Sommer warnt\:', 'Sommer warnt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'einmal gesagt\:', 'einmal gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'gestern gesagt\:', 'gestern gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'eben gesagt\:', 'eben gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'hat gesagt\:', 'hat gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'gesagt hat\:', 'gesagt hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Präsident Trump\:', 'Präsident Trump\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'darauf hinweist\:', 'darauf hinweist\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Erdogan zu\:', 'Erdogan zu\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Vizepräsidentin Roth\:', 'Vizepräsidentin Roth\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'in einem Interview\:', 'in einem Interview\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'sagte auch noch\:', 'sagte auch noch\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'schreibt uns\:', 'schreibt uns\:', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'präsident gesagt\:', 'präsident gesagt :', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'vorgestellt hatte\:', 'vorgestellt hatte\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'gewirkt hat\:', 'gewirkt hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'nach Washington\:', 'nach Washington\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Macron überein\:', 'Macron überein\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'auch ausgeführt\:', 'auch ausgeführt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'es gesagt\:', 'es gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'sagt\:', 'sagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'sagte\:', 'sagte\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'einen Satz\:', 'einen Satz\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'darauf hingewiesen\:', 'darauf hingewiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'hat es angesprochen\:', 'hat es angesprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'gesagt\:', 'gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'sagte damals\:', 'sagte damals\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'gerade schon angesprochen\:', 'gerade schon angesprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'hat es gesagt\:', 'hat es gesagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'das deutlich gemacht\:', 'das deutlich gemacht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'darauf hingewiesen\:', 'darauf hingewiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'hat es angesprochen\:', 'hat es angesprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'worden\:', 'worden :', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'im Ausschuss angekündigt\:', 'im Ausschuss angekündigt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Staatssekretärin sagt\:', 'Staatssekretärin sagt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Infrastruktur auf\:', 'Infrastruktur auf\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'eben\:', 'eben\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'Portugal\:', 'Portugal\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'gemacht\:', 'gemacht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'haben\:', 'haben\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'gesagt worden\:', 'gesagt worden\:', text, flags=re.DOTALL  | re.MULTILINE).strip()      
            text = re.sub(r'sagen\:', 'sagen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()      
            text = re.sub(r'(\([A-ZLÖÄÜ][a-züöäßğéè]+[\s\-][A-ZÖÄÜvindè][ a-züöäßéğè\.]+\s?([A-ZLÖÄÜ][a-züöäßğéè]+)?\s?([\s\-\(]+[A-ZÖÄÜvindè][A-Z a-züöäßéğè\.\)\-]+)?Bundesministeri?n?[A-Za-zöäü\s\n\-]+)(\:)', r'\1\\\2', text, flags=re.DOTALL  | re.MULTILINE)                
            text = re.sub(r'Schütte\: Helft', 'Schütte\: Helft', text, flags=re.DOTALL  | re.MULTILINE).strip()      
            text = re.sub(r'gilt\:', 'gilt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Partner\:', 'Partner\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'nanzen\:Griechenland', 'nanzen\\:Griechenland', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'nanzen\:\nGriechenland', 'nanzen\\:Griechenland', text, flags=re.DOTALL  | re.MULTILINE).strip()            
            text = re.sub(r'nanzen\: Griechenland', 'nanzen\\:Griechenland', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'Antrag des Bundesministeriums der Finan-zen\:', 'Antrag des Bundesministeriums der Finan-zen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Abgabe einer Regierungserklärung durch den\nBundesminister für Gesundheit\:', 'Abgabe einer Regierungserklärung durch den\nBundesminister für Gesundheit\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Griechenland\:', 'Griechenland\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'zen\: Entlastung', 'zen\: Entlastung', text, flags=re.DOTALL  | re.MULTILINE).strip()                      
            text = re.sub(r'nahtlos ein\:', 'nahtlos ein\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                      
            text = re.sub(r'zwei Staatsekre\-\ntäre\:', 'zwei Staatsekretäre\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                        
            text = re.sub(r'Ausschusses\:', 'Ausschusses\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'gewiesen\:', 'gewiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Energie\: Vertrag', 'Energie\: Vertrag', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Äußerung von Staatssekretär Ferlemann:', 'Äußerung von Staatssekretär Ferlemann\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                
            text = re.sub(r'Verkehrsministerium\: Legen', 'Verkehrsministerium\: Legen', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'dieser Republik\:', 'dieser Republik\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'ligt\:', 'ligt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'festgestellt\:', 'festgestellt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'umgeht\:', 'umgeht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'Riesenaufgabenpaket\:', 'Riesenaufgabenpaket\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                       
            text = re.sub(r'auf\:', 'auf\:', text, flags=re.DOTALL  | re.MULTILINE).strip()           
            text = re.sub(r'getoppt\:', 'getoppt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'richtig\:', 'richtig\:', text, flags=re.DOTALL  | re.MULTILINE).strip()           
            text = re.sub(r'sogar\:', 'sogar\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'überein\:', 'überein\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'Frage\:', 'Frage\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'ministerium\: Nehmen', 'ministerium\: Nehmen', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'reden\:', 'reden\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                        
            text = re.sub(r'sen\: Wenn', 'sen\: Wenn', text, flags=re.DOTALL  | re.MULTILINE).strip()                        
            text = re.sub(r'nennen\:', 'nennen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                          
            text = re.sub(r'Antrag ein\:', 'Antrag ein\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'vorwerfen\:', 'vorwerfen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'angesprochen\:', 'angesprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'gefragt\:', 'gefragt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'darf\:', 'darf\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'voranbringt\:', 'voranbringt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'kommt\:', 'kommt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'SPD\-Bundestagsfraktion\:', 'SPD\-Bundestagsfraktion\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'nanzministers\: Weiter so', 'nanzministers\: Weiter so', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'ministerin\: Rufen Sie', 'ministerin\: Rufen Sie', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Bundesministerien\: Es', 'Bundesministerien\: Es', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'völlig zu\:', 'völlig zu\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'gegangen ist\:', 'gegangen ist\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    

            text = re.sub(r'gewandt\:', 'gewandt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'wie folgt\:', 'wie folgt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'ich\:', 'ich\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'verabschiedet\:', 'verabschiedet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'fokussieren\:', 'fokussieren\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'vorbereitet\:', 'vorbereitet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'kennen\:', 'kennen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Bundeswehr\:', 'Bundeswehr\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'angedeutet\:', 'angedeutet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'geht\:', 'geht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Bundeswehr\:', 'Bundeswehr\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'kann\:', 'kann\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r' hat\:', ' hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Titel\:', 'Titel\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'zuschrieb\:', 'zuschrieb\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'gehört\:', 'gehört\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'zurück\:', 'zurück\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'gewandt\:', 'gewandt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'den Weg\:', 'den Weg\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Pressekonferenz\:', 'Pressekonferenz\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'gehört\:', 'gehört\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'fragen\:', 'fragen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'ministerium\:', 'ministerium\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'wollen\:', 'wollen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'hinzu\:', 'hinzu\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  

            text = re.sub(r'file\:', 'file\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'fragen\:', 'fragen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r' ein\:', ' ein\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r' hat\:', ' hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'spre-\nchen\:', 'spre-\nchen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'interessiert\:', 'interessiert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r' ist\:', ' ist\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r' hat\:', ' hat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'Frankreichs\:', 'Frankreichs\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'entdeckt\:', 'entdeckt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'ministerium an\:', 'ministerium an\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'Ebe-\nnen\:', 'Ebe-\nnen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                
            text = re.sub(r'hinterlas-\nsen\:', 'Ebe-\nsen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'bedanken\:', 'bedanken\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'Affen\:', 'Affen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'ausgeführt\:', 'ausgeführt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'eingesetzt\:', 'eingesetzt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'ausweichend\:', 'ausweichend\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'antwortet\:', 'antwortet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'darstellen\:', 'darstellen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'gezogen\:', 'gezogen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'ha-\nben\:', 'ha-\nben\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'gezeigt\:', 'gezeigt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'ausgeführt\:', 'ausgeführt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'Ergebnis\:', 'Ergebnis\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'gebrauchen\:', 'gebrauchen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'klar\:', 'klar\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'gestalten\:', 'gestalten\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'Mitarbeiter\:', 'Mitarbeiter\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'Punkt\:', 'Punkt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'geschildert\:', 'geschildert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'sind\:', 'sind\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'unmittelbar\:', 'unmittelbar\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'Gauland\:', 'Gauland\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'bewiesen\:', 'bewiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'zugestehen\:', 'zugestehen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'klarmacht\:', 'klarmacht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'\nhat\:', '\nhat\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'lautet\:', 'lautet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'muss\:', 'muss\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'konkret\:', 'erklärt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'ge-\nwandt\:', 'ge-\nwandt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                                   
            text = re.sub(r'gibt\:', 'gibt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'demonstriert\:', 'demonstriert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                                                  
            text = re.sub(r'meint\:', 'meint\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'wichtig\:', 'wichtig\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                                                 
            text = re.sub(r'meint\:', 'meint\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                
            text = re.sub(r'gestartet\:', 'gestartet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Weitblick\:', 'Weitblick\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'stehen\:', 'stehen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'geschildert\:', 'geschildert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'1\) Ergebnis Seite 12693 C', '', text, flags=re.DOTALL  | re.MULTILINE).strip()

            text = re.sub(r'wird\:', 'wird\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'geprüft\:', 'geprüft\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'Fra-\ngen\:', 'Fra-\ngen\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'wis-\nsen\:', 'wis-\nsen\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'oder nicht\:', 'oder nicht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'wurden\:', 'wurden\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'fragt\:', 'fragt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'erklärt\:', 'erklärt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'misslos\:', 'misslos\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'dergrund\:', 'dergrund\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Worten\:', 'Worten\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'gerichtet\:', 'gerichtet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'ausgelegt\:', 'ausgelegt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'Innenpolitik aus\:', 'Innenpolitik aus\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'Parole\:', 'Parole\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'dargetan\:', 'dargetan\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'noch\:', 'noch\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'gaben\:', 'gaben\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'nommen\:', 'nommen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                        
            text = re.sub(r'ange-\nnommen\:', 'ange-\nnommen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                         
            text = re.sub(r'ge-\nmacht\:', 'ge-\nmacht\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 

            text = re.sub(r'dazu\:', 'dazu\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                   
            text = re.sub(r'bekannt\:', 'bekannt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'treffen\:', 'treffen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'Wimmer zu\:', 'Wimmer zu\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'facto ab\:', 'facto ab\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'stellt\:', 'stellt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'formuliert\:', 'formuliert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'gedacht\:', 'gedacht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'wurde\:', 'wurde\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Zeit\:', 'Zeit\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'macht\:', 'macht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'benannt\:', 'benannt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'richtet\:', 'richtet\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'auffor-\ndern\:', 'auffor-\ndern\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'hervorrufen\:', 'hervorrufen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'aufgefallen\:', 'aufgefallen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'lautete\:', 'lautete\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'unterbreitet\:', 'unterbreitet\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'war\:', 'war\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'positionieren\:', 'positionieren\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'rekurrieren\:', 'rekurrieren\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'überlegen\:', 'überlegen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'besonderer\:', 'besonderer\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'denken\:', 'denken\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'Jahres\:', 'Jahres\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 

            text = re.sub(r'genannt\:', 'genannt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                
            text = re.sub(r'geändert\:', 'geändert\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Etatdebatte\:', 'Etatdebatte\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'schreiben Sie\:', 'schreiben Sie\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                
            text = re.sub(r'gehalten\:', 'gehalten\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'gebracht\:', 'gebracht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'wiederholen\:', 'wiederholen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                
            text = re.sub(r'ergänzt\:', 'ergänzt\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'sehe\:', 'sehe\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'damals\:', 'damals\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'dargestellt\:', 'dargestellt\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'zusammengefasst\:', 'zusammengefasst\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'würde\:', 'würde\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'habe\:', 'habe\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'Ihnen\:', 'Ihnen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'zitiert\:', 'zitiert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                   
            text = re.sub(r'verstanden\:', 'verstanden\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'plädiert\:', 'plädiert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'erfahren\:', 'erfahren\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'besprochen\:', 'besprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                  
            text = re.sub(r'angespro-\nchen\:', 'angespro-\nchen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'gebracht\:', 'gebracht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'Scholz\: die Arbeitslosenversicherung', 'Scholz\: die Arbeitslosenversicherung', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Zitat von Außen-\nminister Maas\:', 'Zitat von Außen-\nminister Maas\:', text, flags=re.DOTALL  | re.MULTILINE).strip()          
            text = re.sub(r'Bundesministerin\:\nNein\!', 'Bundesministerin\:\nNein\!', text, flags=re.DOTALL  | re.MULTILINE).strip()          
            text = re.sub(r'Staatsministerin\: Natürlich', 'Staatsministerin\: Natürlich', text, flags=re.DOTALL  | re.MULTILINE).strip()          
            text = re.sub(r'Staatsministerin\: Doch\!', 'Staatsministerin\: Doch\!', text, flags=re.DOTALL  | re.MULTILINE).strip()          
            text = re.sub(r'Staatsministerin\: Ach so\!', 'Staatsministerin\: Ach so!', text, flags=re.DOTALL  | re.MULTILINE).strip()          
            text = re.sub(r'Finanzministers\:\n\„Es', 'Finanzministers\:\n\„Es', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'Frau Bundeskanzlerin\:', 'Frau Bundeskanzlerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Bundeskanzlerin\: Eben\!\)', 'Bundeskanzlerin\: Eben!)', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'an die Bundeskanzlerin\:', 'an die Bundeskanzlerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'meine Finanzministerin\:', 'meine Finanzministerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'Frau Bundesumweltministerin\:', 'Frau Bundesumweltministerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'eines Umweltministers\:', 'eines Umweltministers\:', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'pauschal gefasst\:', 'pauschal gefasst\:', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'hat vollmundig versprochen\:', 'hat vollmundig versprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                
            text = re.sub(r'Folgetag\:', 'Folgetag\:', text, flags=re.DOTALL  | re.MULTILINE).strip()       
            text = re.sub(r'erinnert worden \:', 'erinnert worden \:', text, flags=re.DOTALL  | re.MULTILINE).strip()         
            text = re.sub(r'Irland\:', 'Irland\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'vor\:', 'vor\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'völlig recht\:', 'völlig recht\:', text, flags=re.DOTALL  | re.MULTILINE).strip()           
            text = re.sub(r'Motto\:', 'Motto\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'versprochen\:', 'versprochen\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Wahrheitsfindung\:', 'Wahrheitsfindung\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'beschlossen\:', 'beschlossen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'hinzuzufügen\:', 'hinzuzufügen\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Horst Seehofer\:', 'Horst Seehofer\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'zitieren\:', 'zitieren\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'ganz offen\:', 'ganz offen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'beantworten\:', 'beantworten\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'gefordert\:', 'gefordert\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'völlig recht\:', 'völlig recht\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'kungsverbot\:', 'kungsverbot\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'worden \:', 'worden \:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'dazu nur\:', 'dazu nur\:', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'wiesen\:', 'wiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()            
            text = re.sub(r'wiesen\:', 'wiesen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'des Bundeswirtschaftsministers\:', 'des Bundeswirtschaftsministers\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'des Wirtschaftsministers\:', 'des Wirtschaftsministers\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'Verbraucherschutz\: Die Frage 1', 'Verbraucherschutz\: Die Frage 1', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'und Soziales\: Die Frage 2', 'und Soziales\: Die Frage 2', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'Verkehrsministeriums\: Mit', 'Verkehrsministeriums\: Mit', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'der Bundeskanzlerin\: erst', 'der Bundeskanzlerin\: erst', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'zitiere die Bundeskanzlerin\:', 'zitiere die Bundeskanzlerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'Bundeskanzlerin\: Besser als', 'Bundeskanzlerin\: Besser als', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Herr Bundesminister Altmaier\:', 'Herr Bundesminister Altmaier\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Anders die Bundeskanzlerin\:', 'Anders die Bundeskanzlerin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Krisenabteilung des Innenministeriums\:', 'Krisenabteilung des Innenministeriums\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'tag\: \„die höchste', 'tag\: „die höchste', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'Verteidigungsministerin\: Es', 'Verteidigungsministerin\: Es', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'der Bundeskanzlerin\: \„Tun', 'der Bundeskanzlerin\: \„Tun', text, flags=re.DOTALL  | re.MULTILINE).strip()   
                               
            
            
            
            
            text = re.sub(r'rium\: \„Jetzt', 'rium\: \„Jetzt', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'rium\: Was', 'rium\: Was', text, flags=re.DOTALL  | re.MULTILINE).strip()             
            text = re.sub(r'ministers\: \„', 'ministers\: „', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'minister\: \„', 'minister\: „', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'ministerin\: \„', 'ministerin\: „', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'ministerin\: Hören', 'ministerin\: Hören', text, flags=re.DOTALL  | re.MULTILINE).strip()      
            text = re.sub(r'Bundesregierung\: Sind Sie', 'Bundesregierung\: Sind Sie', text, flags=re.DOTALL  | re.MULTILINE).strip()      
            text = re.sub(r'Müller\: Hö', 'Müller\: Hö', text, flags=re.DOTALL  | re.MULTILINE).strip()         
            text = re.sub(r'Kanzleramt\: Es wird ', 'Kanzleramt\: Es wird ', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Kultusministerkonferenz\: Ein', 'Kultusministerkonferenz\: Ein', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Julia Klöckner\: Ja\,', 'Julia Klöckner\: Ja\,', text, flags=re.DOTALL  | re.MULTILINE).strip() 
            text = re.sub(r'Justizministerin\: Wenn', 'Justizministerin\: Wenn', text, flags=re.DOTALL  | re.MULTILINE).strip()     
            text = re.sub(r'Bundesfinanzministeriums\: Die zeitliche', 'Bundesfinanzministeriums\: Die zeitliche', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'ums\: Sie', 'ums\: Sie', text, flags=re.DOTALL  | re.MULTILINE).strip()                    
            text = re.sub(r'Justizministerin\: Wir', 'Justizministerin\: Wir', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Gabriel\: Warum stoppen', 'Gabriel\: Warum stoppen', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'diesem Pult aus\:', 'diesem Pult aus\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                     
            text = re.sub(r'Frau Ministerin\: Ich', 'Frau Ministerin\: Ich', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'ministerin\: Auch', 'ministerin\: Auch', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Bundesverkehrsministeriums\: Bei', 'Bundesverkehrsministeriums\: Bei', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Umweltministeriums\:\nIm', 'Umweltministeriums\:\nIm', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Antrag des\nBundesministeriums der Finanzen\:', 'Antrag des Bundesministeriums der Finanzen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                             
            text = re.sub(r'Antrag des Bundesministeriums der Finanzen\:', 'Antrag des Bundesministeriums der Finanzen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                             
            text = re.sub(r'Bundesbildungsministerin\: nichts', 'Bundesbildungsministerin\: nichts', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Bundesministerin\: Aber', 'Bundesministerin\: Aber', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Frau Justizministerin\: Es', 'Frau Justizministerin\: Es', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Andreas Scheuer\: Doch\!', 'Andreas Scheuer\: Doch\!', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'neuen Bundesfinanzministers Scholz\:', 'neuen Bundesfinanzministers Scholz\:', text, flags=re.DOTALL  | re.MULTILINE).strip()    
            text = re.sub(r'Staatssekretär Gebhart\: Wie', 'Staatssekretär Gebhart\: Wie', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                               
            text = re.sub(r'ministerium immer\:', 'ministerium immer\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                               
            text = re.sub(r'Edward Gray zutraf\:', 'Edward Gray zutraf\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                               
            text = re.sub(r'einer Rede\:', 'einer Rede\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                               
            text = re.sub(r'Papier des Bundes-\ninnenministeriums\:', 'Papier des Bundes-\ninnenministeriums\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                                                                                      
            text = re.sub(r'Frau Kollegin Konrad\: Niemand', 'Frau Kollegin Konrad\: Niemand', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'Zahlen des Bundeswirtschaftsministeriums\:', 'Zahlen des Bundeswirtschaftsministeriums\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'Herr Bundesminister\n\nHeil\:', 'Herr Bundesminister Heil\:', text, flags=re.DOTALL  | re.MULTILINE).strip()               
            text = re.sub(r'dent Putin\:', 'dent Putin\:', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'von der Leyen\: Die', 'von der Leyen\: Die', text, flags=re.DOTALL  | re.MULTILINE).strip()              
            text = re.sub(r'Verordnung des\nBundesministeriums der Finanzen\:', 'Verordnung des\nBundesministeriums der Finanzen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Verordnung\ndes Bundesministeriums der Finanzen\:', 'Verordnung des\nBundesministeriums der Finanzen\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'beten\:', 'beten\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                       
            text = re.sub(r'für Ernährung und Landwirtschaft\:', 'für Ernährung und Landwirtschaft\:', text, flags=re.DOTALL  | re.MULTILINE).strip()                 
            text = re.sub(r'Griechenlands\:', 'Griechenlands\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   
            text = re.sub(r'CSU\: Seit', 'CSU\: Seit', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'nun fort\:', 'nun fort\:', text, flags=re.DOTALL  | re.MULTILINE).strip()  
            text = re.sub(r'durch die\nBundesministerin der Verteidigung\:', 'durch die\nBundesministerin der Verteidigung\:', text, flags=re.DOTALL  | re.MULTILINE).strip()   

            
            text = re.sub(r'Zeit\n', 'Zeit\.\n', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'\n\nHerr Kollege', '\nHerr Kollege', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Indymedia selbst\:', 'Indymedia selbst\:', text, flags=re.DOTALL  | re.MULTILINE).strip()
            text = re.sub(r'Vizepräsident in', 'Vizepräsidentin', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'([A-Za-zöäüéßğÖÄÜ]+) (Vizepräsident)', r'\1\n\2', text)
            text = re.sub(r'(\(Monika Grütters Staatsministerin)(\:)', r'\1\\\2', text)
            text = re.sub(r'([A-Za-zöäüéßğÖÄÜ]+) (Vizepräsidentin)', r'\1\n\2', text)
            text = re.sub(r'([A-Za-zöäüéßğÖÄÜ]+) (Präsident)', r'\1\n\2', text)
            text = re.sub(r'([A-Za-zöäüéßğÖÄÜ]+) (Präsidentin)', r'\1\n\2', text)
            text = re.sub(r'\nJetzt meine Frage:', '\:', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub(r'BMBF\-Staatssekretär Georg Schütte\: Helft', 'BMBF-Staatssekretär Georg Schütte : Helft', text, flags=re.DOTALL  | re.MULTILINE)
            text = re.sub('Bündnis\s?90[\nA-Za-zÜü \-]+(N|n)', 'Grüne', text, flags=re.DOTALL | re.MULTILINE)
            text = re.sub('BÜNDNIS\s?90[\nA-Za-zÜü \-]+(N|n)', 'Grüne', text, flags=re.DOTALL | re.MULTILINE)
            text = re.sub(' \n', '\n', text)
            text = re.sub('\n ', '\n', text) 
            text = re.sub('  ', ' ', text)
            text = re.sub('\:\n\n', ':\n', text) 
            #text = re.sub('\–\n\n', '\–\n', text) 
            text = re.sub('\nVizepräsident', '\n\nVizepräsident', text) 
            text = re.sub('\nPräsident', '\n\nPräsident', text) 
            text = re.sub('\s\.', '.', text) 
            text = re.sub('\n\nVielen Dank\.', '\nVielen Dank.', text) 
            text = re.sub(r'1\) Anlage 10', r'\n\n', text)
            text = re.sub(r'1\) Anlage 2', r'\n\n', text)
            text = re.sub(r'1\) Namensverzeichnis der Teilnehmer an der Wahl siehe Anlage 6', r'\n\n', text)            

            
            
            
            
            text = re.sub(r'(\n\(.*?)\((.*?\)\n)', r'\1\[\2', text)
            text = re.sub(r'(\n\(.*?)\)(.*?\)\n)', r'\1\]\2', text)
            text = re.sub(r'([A-Za-z]+)\n\n([A-Za-z]+)', r'\1\n\2', text)       
            #text = re.sub(r'([A-Za-z]+\?)\n\n([A-Za-z]+)', r'\1\n\2', text)  
            text = re.sub(r'([A-Za-z]+[\.\s\–]+)\n\n(Herr [A-Za-z]+)', r'\1\n\2', text)  
            text = re.sub(r'([A-Za-z]+[\.\s\–]+)\n\n(Frau [A-Za-z]+)', r'\1\n\2', text) 
            text = re.sub(r'(\,)\n\n([A-Za-z]+)', r'\1\n\2', text) 
            text = re.sub(r'(html\)\?)\n\n(Frau [A-Za-z]+)', r'\1\n\2', text)  
            text = re.sub(r'(html\)\?)\n\n(Herr [A-Za-z]+)', r'\1\n\2', text)  
            text = re.sub(r'(\)\?)\n\n(Frau [A-Za-z]+)', r'\1\n\2', text)  
            text = re.sub(r'(\)\?)\n\n(Herr [A-Za-z]+)', r'\1\n\2', text) 
            text = re.sub(r'(\!)\n\n(Herr [A-Za-z]+)', r'\1\n\2', text) 
            text = re.sub(r'(\!)\n\n(Frau [A-Za-z]+)', r'\1\n\2', text) 
            text = re.sub(r'(Vizepräsidentin Claudia Roth\:)\n(Nina Warken)', r'\1\n\n\n\n\2', text)  
            text = re.sub('\n\nHerr Staatsminister.', '\nHerr Staatsminister.', text) 
            text = re.sub('bei der AfD\n', 'bei der AfD)\n\n', text) 
            text = re.sub('\n\nFrau Staatsministerin.', '\nFrau Staatsministerin.', text)  
            text = re.sub('\n\nFrau Bundesministerin.', '\nFrau Bundesministerin.', text) 
            text = re.sub('\n\nFrau Staatssekretärin.', '\nFrau Staatssekretärin.', text) 
            text = re.sub('\n\nHerr Bundesministerin.', '\nHerr Bundesministerin.', text)  
            text = re.sub('\n\nHerr Staatssekretär.', '\nHerr Staatssekretär.', text)  
            text = re.sub('\n\nFrau Müntefering.', '\nFrau Müntefering.', text)
            text = re.sub('Grüne Bayram', 'Canan Bayram', text)
            text = re.sub('Frau Tiemann\n', 'Frau Tiemann\n\n', text)
            text = re.sub('Turnusende', 'Turnusende\n\n', text)
            text = re.sub('Beifall bei der CDUCSU\n', 'Beifall bei der CDUCSU)\n\n', text)
            text = re.sub('1\) Anlage 3', '', text)
            text = re.sub('2\) Ergebnis Seite 373 D', '', text)
            text = re.sub('\n\nJedenfalls vermute ich das\.', '\nJedenfalls vermute ich das', text)
            text = re.sub('\n\n\n', '\n\n', text)
            text = re.sub(r'(.*?\.)\n\n(.*?\.\n\n)', r'\1\n\2', text)  
            text = re.sub(r'(.*?\))\n\n(.*?\.\n\n)', r'\1\n\2', text) 
            
            text = '\n\n' + text
            
            return text
